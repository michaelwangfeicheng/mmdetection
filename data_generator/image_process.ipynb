# %%
import os
import numpy as np
import cv2 as cv
import json
import re
from PIL import Image, ImageDraw

import matplotlib.pyplot as plt
import platform

from image_preprocess import *

# %% [markdown]
# # 渐变处理

# %%
img_path = os.path.join(os.getcwd(),'data', 'objects', 'round_seal',
                         'TCL科技集团股份有限公司_www.395.net.cn_alpha.png')
# img = imshow_cv(img_path,flag=cv.IMREAD_UNCHANGED)
img = imread_cv(img_path)
print(img.shape)
plt.imshow(img)
# Out:
# (160, 160, 4)

# %%
np.random.random()
# Out:
# 0.7034596520717239

# %%
img_eroded_alpha = erode_image(img,show=True)

# %%
img_eroded_alpha = erode_image(img,show=True)

# %%
   
im_processed_write(img_eroded_alpha, img_path)

# %%
# 提取 alpha通道
# if blended.shape[-1]==4:
#     *_,alpha = cv.split(img)

# alpha = np.expand_dims(alpha,axis=2)
# img_eroded_alpha = np.concatenate([blended2,alpha],axis=2)
# b,g,r = cv.split(blended2)
# img_eroded_alpha = cv.merge((blended2,alpha))
# print(img_eroded_alpha.shape)
